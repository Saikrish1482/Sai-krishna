# %%
import pandas as custlifepn

life1 = custlifepn.read_csv("Returns.csv")
life2 = custlifepn.read_csv("Suppliers.csv")
life3 = custlifepn.read_csv("Customers.csv")
life4 = custlifepn.read_csv("Orders.csv")
life5 = custlifepn.read_csv("Payment_info.csv")
life6 = custlifepn.read_csv("Products.csv")

# %%
print("Returns Data Shape      = ", life1.shape)
print("Suppliers Data Shape    = ", life2.shape)
print("Customers Data Shape    = ", life3.shape)
print("Orders Data Shape       = ", life4.shape)
print("Payment Info Data Shape = ", life5.shape)
print("Products Data Shape     = ", life6.shape)
# Out:
# Returns Data Shape      =  (9813, 4)
# Suppliers Data Shape    =  (100010, 8)
# Customers Data Shape    =  (8305, 9)
# Orders Data Shape       =  (100010, 8)
# Payment Info Data Shape =  (100010, 6)
# Products Data Shape     =  (100010, 5)

# %%
life1.head()
# Out:
#    order_id  customer_id         return_reason return_status
# 0         1            1             Defective     Delivered
# 1         7            2         Too Expensive  Not Accepted
# 2        12            3         Too Expensive  Not Accepted
# 3        25           12  Found a Better Price  Not Accepted
# 4        45           11             Defective          Sent

# %%
life2.head()
# Out:
#    seller_id  product_id                    seller_name    contact_name  \
# 0          1           1                       King LLC   Douglas Black
# 1          2           2  Aguirre, Taylor and Rodriguez      Amy Weaver
# 2          3           3                    Chang-Young  Cynthia Tanner
# 3          4           4           Patel, Lucas and Key    Kathy Torres
# 4          5           5        Brown, Fisher and Baker       Lisa Reed
#
#               contact_email       contact_phone                   country  \
# 0     heather72@example.net       (620)979-8774              Cook Islands
# 1  camposcheryl@example.net  479-323-7120x73535                   Vietnam
# 2   farmerjulie@example.net        848-986-8439                  Suriname
# 3  torresmonica@example.org  903.432.8277x24755  Turks and Caicos Islands
# 4   ericapeters@example.org  (873)614-7366x7177                     Malta
#
#    product_count
# 0        6659199
# 1            401
# 2      555542479
# 3              7
# 4            391

# %%
life3.head()
# Out:
#    customer_id first_name last_name                     email  \
# 0            1    Valerie  Gonzalez  brownkristen@example.net
# 1            2   Kathleen    Patton     kristin93@example.net
# 2            3      Paula      Rice       yrivera@example.net
# 3            4       Mary   Jimenez       chloe23@example.com
# 4            5      Ralph    Barron      sandra97@example.net
#
#                     phone            country          city  \
# 0   001-902-803-8052x4565           Malaysia   Anthonybury
# 1    001-415-964-2771x416           Suriname  Stephensbury
# 2            899.837.6456             Israel     Damonberg
# 3  001-306-689-6522x18056  Wallis and Futuna     Perezside
# 4            971.553.8749          Hong Kong    Milesshire
#
#                                              address           created_at
# 0    381 Ronnie Mills Suite 270\nCohentown, DC 34488  2022-12-15T18:26:14
# 1  462 Jacob Hill Suite 180\nLake Mirandachester,...  2020-01-10T11:43:16
# 2   58011 Justin Flats\nSouth Daniellebury, MT 59037  2017-11-21T05:35:18
# 3     377 Stephanie Expressway\nWest Linda, MT 78170  2022-01-05T18:18:35
# 4    58576 Proctor Manor\nNorth Robertport, FM 15621  2024-05-17T02:40:10

# %%
life4.tail()
# Out:
#         order_id  product_id  customer_id           order_date     status  \
# 100005    100006       94349         6694  2023-07-02 05:04:00  Delivered
# 100006    100007       25787         5040  2024-07-01 16:27:10  Delivered
# 100007    100008       84542         5531  2023-06-21 14:22:48  Delivered
# 100008    100009       31849         3165  2024-08-17 06:50:22   Received
# 100009    100010       49849         7379  2024-05-02 12:44:27  Delivered
#
#         quantity  unit_price  total_price
# 100005        11       18.99       208.89
# 100006        18       76.20      1371.60
# 100007         1       36.99        36.99
# 100008        14       18.45       258.30
# 100009         4       89.99       359.96

# %%
life5.tail()
# Out:
#         payment_id  order_id    name_on_card       card_number card_expire  \
# 100005      100006    100006    Daniel Blair     4079146233226       01/32
# 100006      100007    100007    Jessica Rice  3586398235079567       08/28
# 100007      100008    100008      Lori Silva  6011818472694370       08/30
# 100008      100009    100009     Robin Ramos   180087569769093       05/28
# 100009      100010    100010  Douglas Warren    30047347761657       02/27
#
#         cvv_number
# 100005         882
# 100006         111
# 100007         911
# 100008          76
# 100009         959

# %%
life6.tail()
# Out:
#         product_id                                       product_name  \
# 100005      100006  Seagate Barracuda 1 TB 7200RPM SATA 32 MB Cach...
# 100006      100007  Waterproof Food Grade Silicone Lubricant Plumb...
# 100007      100008       Amplitude Composite Toe Waterproof Work Boot
# 100008      100009  925 Sterling Silver Lab Opal Heart Urn Ring fo...
# 100009      100010  Coats: Yarn Red Heart Boutique Sashay Sparkle ...
#
#                            category   price  stock_status
# 100005                 Data Storage   59.99      In Stock
# 100006      Industrial & Scientific    6.99  Out of Stock
# 100007                  Men's Shoes  172.00      In Stock
# 100008               Girls' Jewelry   29.99  Out of Stock
# 100009  Knitting & Crochet Supplies   11.42      In Stock

# %%
sample_life1 = life1[0:1000]

file_path = r"sample_life1.csv"
sample_life1.to_csv(file_path, index=False)

# %%
sample_life2 = life2[0:1000]

file_path = r"sample_life2.csv"
sample_life2.to_csv(file_path, index=False)

# %%
sample_life3 = life3[0:1000]

file_path = r"sample_life3.csv"
sample_life3.to_csv(file_path, index=False)

# %%
sample_life4 = life4[0:1000]

file_path = r"sample_life4.csv"
sample_life4.to_csv(file_path, index=False)

# %%
sample_life5 = life5[0:1000]

file_path = r"sample_life5.csv"
sample_life5.to_csv(file_path, index=False)

# %%
sample_life6 = life6[0:1000]

file_path = r"sample_life6.csv"
sample_life6.to_csv(file_path, index=False)

# %%
## Merging Data Frame 1
merge1 = custlifepn.merge(life3, life4, on='customer_id', suffixes=('_df1', '_df2'))
print("Merged DataFrame1 with suffixes:")
merge1.info()
# Out:
# Merged DataFrame1 with suffixes:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100010 entries, 0 to 100009
# Data columns (total 16 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   customer_id  100010 non-null  int64
#  1   first_name   100010 non-null  object
#  2   last_name    100010 non-null  object
#  3   email        100010 non-null  object
#  4   phone        100010 non-null  object
#  5   country      100010 non-null  object
#  6   city         100010 non-null  object
#  7   address      100010 non-null  object
#  8   created_at   100010 non-null  object
#  9   order_id     100010 non-null  int64
#  10  product_id   100010 non-null  int64
#  11  order_date   100010 non-null  object
#  12  status       100010 non-null  object
#  13  quantity     100010 non-null  int64
#  14  unit_price   100010 non-null  float64
#  15  total_price  100010 non-null  float64
# dtypes: float64(2), int64(4), object(10)
# memory usage: 12.2+ MB

# %%
## Merging Data Frame 2
merge2 = custlifepn.merge(merge1, life5, on= "order_id",suffixes=('_df1', '_df2'))
print("Merged DataFrame2 with suffixes:")
merge2.info()
# Out:
# Merged DataFrame2 with suffixes:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100010 entries, 0 to 100009
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   customer_id   100010 non-null  int64
#  1   first_name    100010 non-null  object
#  2   last_name     100010 non-null  object
#  3   email         100010 non-null  object
#  4   phone         100010 non-null  object
#  5   country       100010 non-null  object
#  6   city          100010 non-null  object
#  7   address       100010 non-null  object
#  8   created_at    100010 non-null  object
#  9   order_id      100010 non-null  int64
#  10  product_id    100010 non-null  int64
#  11  order_date    100010 non-null  object
#  12  status        100010 non-null  object
#  13  quantity      100010 non-null  int64
#  14  unit_price    100010 non-null  float64
#  15  total_price   100010 non-null  float64
#  16  payment_id    100010 non-null  int64
#  17  name_on_card  100010 non-null  object
#  18  card_number   100010 non-null  int64
#  19  card_expire   100010 non-null  object
#  20  cvv_number    100010 non-null  int64
# dtypes: float64(2), int64(7), object(12)
# memory usage: 16.0+ MB

# %%
## Merging Data Frame 3
merge3 = custlifepn.merge(merge2, life6, on= "product_id",suffixes=('_df1', '_df2'))
print("Merged DataFrame3 with suffixes:")
merge3.info()
# Out:
# Merged DataFrame3 with suffixes:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100010 entries, 0 to 100009
# Data columns (total 25 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   customer_id   100010 non-null  int64
#  1   first_name    100010 non-null  object
#  2   last_name     100010 non-null  object
#  3   email         100010 non-null  object
#  4   phone         100010 non-null  object
#  5   country       100010 non-null  object
#  6   city          100010 non-null  object
#  7   address       100010 non-null  object
#  8   created_at    100010 non-null  object
#  9   order_id      100010 non-null  int64
#  10  product_id    100010 non-null  int64
#  11  order_date    100010 non-null  object
#  12  status        100010 non-null  object
#  13  quantity      100010 non-null  int64
#  14  unit_price    100010 non-null  float64
#  15  total_price   100010 non-null  float64
#  16  payment_id    100010 non-null  int64
#  17  name_on_card  100010 non-null  object
#  18  card_number   100010 non-null  int64
#  19  card_expire   100010 non-null  object
#  20  cvv_number    100010 non-null  int64
#  21  product_name  100010 non-null  object
#  22  category      100010 non-null  object
#  23  price         100010 non-null  float64
#  24  stock_status  100010 non-null  object
# dtypes: float64(3), int64(7), object(15)
# memory usage: 19.1+ MB

# %%
## Calculate total revenue per customer
customer_revenue = merge3.groupby('customer_id')['total_price'].sum().reset_index()
customer_revenue.columns = ['customer_id', 'total_revenue']
customer_revenue
# Out:
#       customer_id  total_revenue
# 0               1       25917.05
# 1               2       14981.05
# 2               3        6774.50
# 3               4       15738.81
# 4               5       10831.56
# ...           ...            ...
# 7948         8295         947.94
# 7949         8296         100.00
# 7950         8297         360.81
# 7951         8303         294.95
# 7952         8305           0.00
#
# [7953 rows x 2 columns]

# %%
## Calculate purchase frequency per customer
purchase_frequency = merge3.groupby('customer_id')['order_id'].count().reset_index()
purchase_frequency.columns = ['customer_id', 'purchase_frequency']
purchase_frequency
# Out:
#       customer_id  purchase_frequency
# 0               1                  43
# 1               2                  36
# 2               3                  28
# 3               4                  32
# 4               5                  33
# ...           ...                 ...
# 7948         8295                   1
# 7949         8296                   1
# 7950         8297                   1
# 7951         8303                   1
# 7952         8305                   1
#
# [7953 rows x 2 columns]

# %%
## Calculate average order value per customer
merge3['average_order_value'] = merge3['total_price'] / merge3['quantity']
avg_order_value = merge3.groupby('customer_id')['average_order_value'].mean().reset_index()
avg_order_value.columns = ['customer_id', 'average_order_value']
avg_order_value
# Out:
#       customer_id  average_order_value
# 0               1            48.662093
# 1               2            38.869722
# 2               3            32.446071
# 3               4            34.481250
# 4               5            34.620606
# ...           ...                  ...
# 7948         8295           157.990000
# 7949         8296            10.000000
# 7950         8297            18.990000
# 7951         8303            58.990000
# 7952         8305             0.000000
#
# [7953 rows x 2 columns]

# %%
## Convert date columns to datetime
merge3['order_date'] = custlifepn.to_datetime(merge3['order_date'])
merge3['created_at'] = custlifepn.to_datetime(merge3['created_at'])

# %%
## Calculate customer lifespan in years
merge3['customer_lifespan'] = (merge3['order_date'].max() - merge3.groupby('customer_id')['order_date'].transform('min')).dt.days / 365
lifespan = merge3.groupby('customer_id')['customer_lifespan'].max().reset_index()
lifespan.columns = ['customer_id', 'customer_lifespan']
lifespan
# Out:
#       customer_id  customer_lifespan
# 0               1           1.958904
# 1               2           4.898630
# 2               3           6.578082
# 3               4           2.852055
# 4               5           0.616438
# ...           ...                ...
# 7948         8295           0.517808
# 7949         8296           1.191781
# 7950         8297           1.287671
# 7951         8303           0.391781
# 7952         8305           5.063014
#
# [7953 rows x 2 columns]

# %%
# Merge all metrics
clv_data = customer_revenue.merge(purchase_frequency, on='customer_id')
clv_data = clv_data.merge(avg_order_value, on='customer_id')
clv_data = clv_data.merge(lifespan, on='customer_id')

# Calculate CLV
clv_data['CLV'] = clv_data['average_order_value'] * clv_data['purchase_frequency'] * clv_data['customer_lifespan']

print("Customer Lifetime Value (CLV) data:")
clv_data
# Out:
# Customer Lifetime Value (CLV) data:
#       customer_id  total_revenue  purchase_frequency  average_order_value  \
# 0               1       25917.05                  43            48.662093
# 1               2       14981.05                  36            38.869722
# 2               3        6774.50                  28            32.446071
# 3               4       15738.81                  32            34.481250
# 4               5       10831.56                  33            34.620606
# ...           ...            ...                 ...                  ...
# 7948         8295         947.94                   1           157.990000
# 7949         8296         100.00                   1            10.000000
# 7950         8297         360.81                   1            18.990000
# 7951         8303         294.95                   1            58.990000
# 7952         8305           0.00                   1             0.000000
#
#       customer_lifespan          CLV
# 0              1.958904  4098.948082
# 1              4.898630  6854.702137
# 2              6.578082  5976.121890
# 3              2.852055  3146.957260
# 4              0.616438   704.268493
# ...                 ...          ...
# 7948           0.517808    81.808521
# 7949           1.191781    11.917808
# 7950           1.287671    24.452877
# 7951           0.391781    23.111151
# 7952           5.063014     0.000000
#
# [7953 rows x 6 columns]

# %%
print("Null in Customer Life Value Prediction:",clv_data.isnull().values.sum())
print("Duplicates in Customer Life Value Prediction:",clv_data.duplicated().values.sum())
# Out:
# Null in Customer Life Value Prediction: 0
# Duplicates in Customer Life Value Prediction: 0

# %%
import matplotlib.pyplot as clvmatplt
clvmatplt.hist(clv_data['CLV'],bins=6, color='cyan')
clvmatplt.title('Histogram for CLV')
clvmatplt.show()

# %%
clv_X = clv_data.drop('CLV',axis=1)
clv_Y = clv_data['CLV']

# %%
from sklearn.model_selection import train_test_split as clvtrtst
clvX_tr, clvX_ts, clvY_tr, clvY_ts = clvtrtst(clv_X, clv_Y, test_size=0.2, random_state=12)
print("Training CLV :", clvX_tr.shape)
print("Testing CLV  :", clvX_ts.shape)
# Out:
# Training CLV : (6362, 5)
# Testing CLV  : (1591, 5)

# %%
import math as clvMath
from sklearn.metrics import r2_score as clvR2Scr
from sklearn.metrics import mean_absolute_error as clvMAE
from sklearn.metrics import mean_squared_error as clvMSE
from sklearn.model_selection import GridSearchCV as clvGrdSr

# %% [markdown]
# ### **Decision Tree Regressor**

# %%
from sklearn.tree import DecisionTreeRegressor as clvDecisionTreeReg

clvGridParameters = { 'criterion':['squared_error','friedman_mse','absolute_error','poisson'],
                      'splitter': ['best', 'random'],
                      'max_depth': [5, 10, 2, 3]
                    }

clvMdl = clvDecisionTreeReg()
clvMdl = clvGrdSr(clvMdl, clvGridParameters, cv=2)
clvMdl.fit(clvX_tr.sample(950, random_state=12), clvY_tr.sample(950, random_state=12))
print("Selected Parameters for Decision Tree Regressor:\n")
print(clvMdl.best_params_)
# Out:
# Selected Parameters for Decision Tree Regressor:
#
# {'criterion': 'poisson', 'max_depth': 10, 'splitter': 'random'}

# %%
### Training CLV

clvMdl = clvDecisionTreeReg(**clvMdl.best_params_)
clvMdl.fit(clvX_tr, clvY_tr)
# Out:
# DecisionTreeRegressor(criterion='poisson', max_depth=10, splitter='random')

# %%
### Testing CLV

clvYpred = clvMdl.predict(clvX_ts)
print("\nDecision Tree in Customer Life Value Prediction\n")
print("R2 Score :", clvR2Scr(clvY_ts, clvYpred)*100)
print("MAE      :", clvMAE(clvY_ts, clvYpred))
print("MSE      :", clvMSE(clvY_ts, clvYpred))
print("RMSE     :", clvMath.sqrt(clvMSE(clvY_ts, clvYpred)))
# Out:
# Decision Tree in Customer Life Value Prediction
#
# R2 Score : 86.23266229179131
# MAE      : 561.4786490688754
# MSE      : 2104156.4609516063
# RMSE     : 1450.5710809717689

# %% [markdown]
# ### **Passive Aggressive Regressor**

# %%
from sklearn.linear_model import PassiveAggressiveRegressor as clvPassiveReg

clvGridParameters = { 'C':[1.0, 0.001, 0.05, 0.003],
                      'fit_intercept': [True, False],
                      'max_iter': [500, 300, 200, 100]
                    }

clvMdl = clvPassiveReg()
clvMdl = clvGrdSr(clvMdl, clvGridParameters, cv=2)
clvMdl.fit(clvX_tr.sample(950, random_state=12), clvY_tr.sample(950, random_state=12))
print("Selected Parameters for Passive Aggressive Regressor:\n")
print(clvMdl.best_params_)
# Out:
# Selected Parameters for Passive Aggressive Regressor:
#
# {'C': 0.003, 'fit_intercept': True, 'max_iter': 500}

# %%
### Training CLV

clvMdl = clvPassiveReg(**clvMdl.best_params_)
clvMdl.fit(clvX_tr, clvY_tr)
# Out:
# PassiveAggressiveRegressor(C=0.003, max_iter=500)

# %%
### Testing CLV

clvYpred = clvMdl.predict(clvX_ts)
print("\nPassive Aggressive in Customer Life Value Prediction\n")
print("R2 Score :", clvR2Scr(clvY_ts, clvYpred)*100)
print("MAE      :", clvMAE(clvY_ts, clvYpred))
print("MSE      :", clvMSE(clvY_ts, clvYpred))
print("RMSE     :", clvMath.sqrt(clvMSE(clvY_ts, clvYpred)))
# Out:
# Passive Aggressive in Customer Life Value Prediction
#
# R2 Score : 31.137429420445105
# MAE      : 1623.2441313445845
# MSE      : 10524738.033869267
# RMSE     : 3244.185265034854

# %% [markdown]
# ### **Random Forest Regressor**

# %%
from sklearn.ensemble import RandomForestRegressor as clvRandomForestReg
clvGridParameters = { 'n_estimators':[100, 200, 400],
                      'criterion':['squared_error','friedman_mse','absolute_error','poisson'],
                      'max_depth': [5, 10, 2, 3]
                    }

clvMdl = clvRandomForestReg()
clvMdl = clvGrdSr(clvMdl, clvGridParameters, cv=2)
clvMdl.fit(clvX_tr.sample(950, random_state=12), clvY_tr.sample(950, random_state=12))
print("Selected Parameters for Random Forest Regressor:\n")
print(clvMdl.best_params_)
# Out:
# Selected Parameters for Random Forest Regressor:
#
# {'criterion': 'poisson', 'max_depth': 10, 'n_estimators': 400}

# %%
### Training CLV

clvMdl = clvRandomForestReg(**clvMdl.best_params_)
clvMdl.fit(clvX_tr, clvY_tr)
# Out:
# RandomForestRegressor(criterion='poisson', max_depth=10, n_estimators=400)

# %%
### Testing CLV

clvYpred = clvMdl.predict(clvX_ts)
print("\nRandom Forest in Customer Life Value Prediction\n")
print("R2 Score :", clvR2Scr(clvY_ts, clvYpred)*100)
print("MAE      :", clvMAE(clvY_ts, clvYpred))
print("MSE      :", clvMSE(clvY_ts, clvYpred))
print("RMSE     :", clvMath.sqrt(clvMSE(clvY_ts, clvYpred)))
# Out:
# Random Forest in Customer Life Value Prediction
#
# R2 Score : 89.07822323387477
# MAE      : 392.6531812720904
# MSE      : 1669249.9039818868
# RMSE     : 1291.9945448731146

# %% [markdown]
# ### **Gradient Boosting Regressor**

# %%
from sklearn.ensemble import GradientBoostingRegressor as clvGradientBoostReg

clvGridParameters = { 'loss':['squared_error','absolute_error','huber', 'quantile'],
                      'learning_rate': [0.1, 0.5, 0.001, 1.0],
                      'n_estimators': [100, 200, 400]
                    }

clvMdl = clvGradientBoostReg()
clvMdl = clvGrdSr(clvMdl, clvGridParameters, cv=2)
clvMdl.fit(clvX_tr.sample(950, random_state=12), clvY_tr.sample(950, random_state=12))
print("Selected Parameters for Gradient Boosting Regressor:\n")
print(clvMdl.best_params_)
# Out:
# Selected Parameters for Gradient Boosting Regressor:
#
# {'learning_rate': 0.1, 'loss': 'squared_error', 'n_estimators': 400}

# %%
### Training CLV

clvMdl = clvGradientBoostReg(**clvMdl.best_params_)
clvMdl.fit(clvX_tr, clvY_tr)
# Out:
# GradientBoostingRegressor(n_estimators=400)

# %%
### Testing CLV

clvYpred = clvMdl.predict(clvX_ts)
print("\nGradient Boosting in Customer Life Value Prediction\n")
print("R2 Score :", clvR2Scr(clvY_ts, clvYpred)*100)
print("MAE      :", clvMAE(clvY_ts, clvYpred))
print("MSE      :", clvMSE(clvY_ts, clvYpred))
print("RMSE     :", clvMath.sqrt(clvMSE(clvY_ts, clvYpred)))
# Out:
# Gradient Boosting in Customer Life Value Prediction
#
# R2 Score : 94.23970378778156
# MAE      : 285.5674599068978
# MSE      : 880385.5000017658
# RMSE     : 938.2886016582349

# %% [markdown]
# ## **Combined Algorithms**

# %%
from sklearn.ensemble import VotingRegressor as clVotingReg

# %% [markdown]
# ### **Decision Tree and Passive Aggressive Regressor**

# %%
clvDec = clvDecisionTreeReg(criterion= 'poisson', max_depth= 10, splitter= 'random')
clvPass = clvPassiveReg(C= 0.003, fit_intercept= True, max_iter= 500)

clvMdl = clVotingReg(estimators=[('DTR', clvDec),('PAR', clvPass)])
clvMdl.fit(clvX_tr, clvY_tr)
# Out:
# VotingRegressor(estimators=[('DTR',
#                              DecisionTreeRegressor(criterion='poisson',
#                                                    max_depth=10,
#                                                    splitter='random')),
#                             ('PAR',
#                              PassiveAggressiveRegressor(C=0.003,
#                                                         max_iter=500))])

# %%
print(clvMdl)
# Out:
# VotingRegressor(estimators=[('DTR',
#                              DecisionTreeRegressor(criterion='poisson',
#                                                    max_depth=10,
#                                                    splitter='random')),
#                             ('PAR',
#                              PassiveAggressiveRegressor(C=0.003,
#                                                         max_iter=500))])

# %%
### Testing CLV

clvYpred = clvMdl.predict(clvX_ts)
print("\nCombination of Decision Tree and Passive Aggressive Regressor\n")
print("R2 Score :", clvR2Scr(clvY_ts, clvYpred)*100)
print("MAE      :", clvMAE(clvY_ts, clvYpred))
print("MSE      :", clvMSE(clvY_ts, clvYpred))
print("RMSE     :", clvMath.sqrt(clvMSE(clvY_ts, clvYpred)))
# Out:
# Combination of Decision Tree and Passive Aggressive Regressor
#
# R2 Score : 53.75558278067547
# MAE      : 1535.7242884911132
# MSE      : 7067850.831970637
# RMSE     : 2658.542990431157

# %% [markdown]
# ### **Passive Aggressive and Random Forest Regressor**

# %%
clvPass = clvPassiveReg(C= 0.003, fit_intercept= True, max_iter= 500)
clvRand = clvRandomForestReg(criterion= 'poisson', max_depth= 10, n_estimators= 400)
clvMdl = clVotingReg(estimators=[('PAR', clvPass),('RFR', clvRand)])
clvMdl.fit(clvX_tr, clvY_tr)
# Out:
# VotingRegressor(estimators=[('PAR',
#                              PassiveAggressiveRegressor(C=0.003, max_iter=500)),
#                             ('RFR',
#                              RandomForestRegressor(criterion='poisson',
#                                                    max_depth=10,
#                                                    n_estimators=400))])

# %%
print(clvMdl)
# Out:
# VotingRegressor(estimators=[('PAR',
#                              PassiveAggressiveRegressor(C=0.003, max_iter=500)),
#                             ('RFR',
#                              RandomForestRegressor(criterion='poisson',
#                                                    max_depth=10,
#                                                    n_estimators=400))])

# %%
### Testing CLV

clvYpred = clvMdl.predict(clvX_ts)
print("\nCombination of Passive Aggressive and Random Forest\n")
print("R2 Score :", clvR2Scr(clvY_ts, clvYpred)*100)
print("MAE      :", clvMAE(clvY_ts, clvYpred))
print("MSE      :", clvMSE(clvY_ts, clvYpred))
print("RMSE     :", clvMath.sqrt(clvMSE(clvY_ts, clvYpred)))
# Out:
# Combination of Passive Aggressive and Random Forest
#
# R2 Score : 56.187964665435075
# MAE      : 1208.1843790923901
# MSE      : 6696093.258589768
# RMSE     : 2587.681058127096

# %% [markdown]
# ### **Random Forest and Gradient Boosting Regressor**

# %%
clvRand = clvRandomForestReg(criterion= 'poisson', max_depth= 10, n_estimators= 400)
clvGrad = clvGradientBoostReg(learning_rate= 0.1, loss= 'squared_error', n_estimators= 400)

clvMdl = clVotingReg(estimators=[('RFR', clvRand),('GBR', clvGrad)])
clvMdl.fit(clvX_tr, clvY_tr)
# Out:
# VotingRegressor(estimators=[('RFR',
#                              RandomForestRegressor(criterion='poisson',
#                                                    max_depth=10,
#                                                    n_estimators=400)),
#                             ('GBR',
#                              GradientBoostingRegressor(n_estimators=400))])

# %%
print(clvMdl)
# Out:
# VotingRegressor(estimators=[('RFR',
#                              RandomForestRegressor(criterion='poisson',
#                                                    max_depth=10,
#                                                    n_estimators=400)),
#                             ('GBR',
#                              GradientBoostingRegressor(n_estimators=400))])

# %%
### Testing CLV

clvYpred = clvMdl.predict(clvX_ts)
print("\nCombination of Random Forest and Gradient Boosting Regressor\n")
print("R2 Score :", clvR2Scr(clvY_ts, clvYpred)*100)
print("MAE      :", clvMAE(clvY_ts, clvYpred))
print("MSE      :", clvMSE(clvY_ts, clvYpred))
print("RMSE     :", clvMath.sqrt(clvMSE(clvY_ts, clvYpred)))
# Out:
# Combination of Random Forest and Gradient Boosting Regressor
#
# R2 Score : 92.41578829453063
# MAE      : 309.01894897430543
# MSE      : 1159146.9897461087
# RMSE     : 1076.6368885311838

# %% [markdown]
# ### **Gradient Boosting and Decision Tree Regressor**

# %%
clvGrad = clvGradientBoostReg(learning_rate= 0.1, loss= 'squared_error', n_estimators= 400)
clvDec = clvDecisionTreeReg(criterion= 'poisson', max_depth= 10, splitter= 'random')

clvMdl = clVotingReg(estimators=[('GBR', clvGrad),('DTR', clvDec)])
clvMdl.fit(clvX_tr, clvY_tr)
# Out:
# VotingRegressor(estimators=[('GBR',
#                              GradientBoostingRegressor(n_estimators=400)),
#                             ('DTR',
#                              DecisionTreeRegressor(criterion='poisson',
#                                                    max_depth=10,
#                                                    splitter='random'))])

# %%
print(clvMdl)
# Out:
# VotingRegressor(estimators=[('GBR',
#                              GradientBoostingRegressor(n_estimators=400)),
#                             ('DTR',
#                              DecisionTreeRegressor(criterion='poisson',
#                                                    max_depth=10,
#                                                    splitter='random'))])

# %%
### Testing CLV

clvYpred = clvMdl.predict(clvX_ts)
print("\nCombination of Gradient Boosting and Decision Tree Regressor\n")
print("R2 Score :", clvR2Scr(clvY_ts, clvYpred)*100)
print("MAE      :", clvMAE(clvY_ts, clvYpred))
print("MSE      :", clvMSE(clvY_ts, clvYpred))
print("RMSE     :", clvMath.sqrt(clvMSE(clvY_ts, clvYpred)))
# Out:
# Combination of Gradient Boosting and Decision Tree Regressor
#
# R2 Score : 93.10961661954661
# MAE      : 339.7795371423612
# MSE      : 1053104.4574994298
# RMSE     : 1026.208778709006

# %% [markdown]
# ### **Decision Tree, Passive Aggressive, Random Forest and Gradient Boosting Regressor**

# %%
clvDec = clvDecisionTreeReg(criterion= 'poisson', max_depth= 10, splitter= 'random')
clvPass = clvPassiveReg(C= 0.003, fit_intercept= True, max_iter= 500)
clvRand = clvRandomForestReg(criterion= 'poisson', max_depth= 10, n_estimators= 400)
clvGrad = clvGradientBoostReg(learning_rate= 0.1, loss= 'squared_error', n_estimators= 400)

clvMdl = clVotingReg(estimators=[('DTR', clvDec),('PAR', clvPass),('RFR', clvRand),('GBR', clvGrad)])
clvMdl.fit(clvX_tr, clvY_tr)
# Out:
# VotingRegressor(estimators=[('DTR',
#                              DecisionTreeRegressor(criterion='poisson',
#                                                    max_depth=10,
#                                                    splitter='random')),
#                             ('PAR',
#                              PassiveAggressiveRegressor(C=0.003, max_iter=500)),
#                             ('RFR',
#                              RandomForestRegressor(criterion='poisson',
#                                                    max_depth=10,
#                                                    n_estimators=400)),
#                             ('GBR',
#                              GradientBoostingRegressor(n_estimators=400))])

# %%
print(clvMdl)
# Out:
# VotingRegressor(estimators=[('DTR',
#                              DecisionTreeRegressor(criterion='poisson',
#                                                    max_depth=10,
#                                                    splitter='random')),
#                             ('PAR',
#                              PassiveAggressiveRegressor(C=0.003, max_iter=500)),
#                             ('RFR',
#                              RandomForestRegressor(criterion='poisson',
#                                                    max_depth=10,
#                                                    n_estimators=400)),
#                             ('GBR',
#                              GradientBoostingRegressor(n_estimators=400))])

# %%
### Testing CLV

clvYpred = clvMdl.predict(clvX_ts)
print("\nCombination of Decision Tree, Passive Aggressive, Random Forest and Gradient Boosting Regressors\n")
print("R2 Score :", clvR2Scr(clvY_ts, clvYpred)*100)
print("MAE      :", clvMAE(clvY_ts, clvYpred))
print("MSE      :", clvMSE(clvY_ts, clvYpred))
print("RMSE     :", clvMath.sqrt(clvMSE(clvY_ts, clvYpred)))
# Out:
# Combination of Decision Tree, Passive Aggressive, Random Forest and Gradient Boosting Regressors
#
# R2 Score : 85.6866424703428
# MAE      : 538.8681654509725
# MSE      : 2187608.407831901
# RMSE     : 1479.0565938570103
